# %%
import numpy
import numpy as np

# %%
m = 5
c = -1
x = [0, 1, 2, 3, 4, 5, 6]

# %%
# task: use a list comprehension to create the output y values
# note how we can't simply write y = m*x + c
# one line of code here:
y = m*x + c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 4
#       1 # task: use a list comprehension to create the output y values
#       2 # note how we can't simply write y = m*x + c
#       3 # one line of code here:
# ----> 4 y = m*x + c
#
# TypeError: can only concatenate list (not "int") to list

# %%
X = np.array(x)
Y = m*X + c

# %%
print(Y)
# Out:
# [-1  4  9 14 19 24 29]

# %%
import matplotlib.pyplot as plt

# %%
    import numpy as np
    import matplotlib.pyplot as plt

    x = np.arange(0, 5, 0.1)
    y = np.sin(x)
    fig, ax = plt.subplots()
    ax.scatter(x, y)

# %%
    import numpy as np
    import matplotlib.pyplot as plt

    x = np.arange(0, 5, 0.1)
    y = np.sin(x)
    plt.scatter(x, y)
